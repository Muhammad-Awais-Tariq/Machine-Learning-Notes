# %% [markdown]
# ## Reinforcement Learning

# %% [markdown]
# ![](Images/reinforcement_learning.png)

# %% [markdown]
# Its not applied to lot of commercial products but its one of the pillars of ml

# %% [markdown]
# If we want to move for example an helicopter with the help of the reinforcement learning we will have the position of the helicopter and then based on the position we will decide how to move the control sticks to move the helicopter

# %% [markdown]
# The position of the helicopter is called the state in the reinforcement learning and moving the control sticks is called action

# %% [markdown]
# For most of the real world examples like flying a helicopter or operating a robot the supervised learning approach does not work well as the conditions in the real world are not ideal and we can not have the data for all the conditions to train the model on

# %% [markdown]
# In the reinforcement learning we use a reward function which gives a positive feedback to the algorithm whenever it does a good work

# %% [markdown]
# Reinforcement learning is powerfull beacuse in it we tell the model what to do not how to do it and we tell it a reward function and it does that

# %% [markdown]
# ## Application of reinforcment learning

# %% [markdown]
# - Controlling the robots
# - Factory optimization
# - Stock trading
# - Playing games

# %% [markdown]
# ![](Images/applications.png)

# %% [markdown]
# ### Mars Rover Example

# %% [markdown]
#  ![](Images/rover_intial.png)

# %% [markdown]
# This is the intial state of the rover for example like this there are 6 states each position where the rover can move is called a state

# %% [markdown]
# ![](Images/rover_Second.png)

# %% [markdown]
# There are two places on the mars and we want to decide which way to go and we can specifiy which is better based on the reward function wherever  the reward is higher it will go there

# %% [markdown]
# The robot has two actions that are left or right

# %% [markdown]
# The final state is called terminal state where nothing happen after that state

# %% [markdown]
# ![](Images/robot_actions.png)

# %% [markdown]
# Based on the intial position the robot can make differect actions it can state from the intial position and go left left and reach the 100 points it can also go right right and reach 60 or it can go right right then left further increasing the path

# %% [markdown]
# In ever step the robot is in some state S , It can choose a certain action a , It get a some reward as well at that state R(S) and based on that it get to new state S`

# %% [markdown]
# ## Return in the reinforcement Learning

# %% [markdown]
# ![](Images/return.png)

# %% [markdown]
# The return captures that small rewards that you can get quickly can be better then the large reward that will take you a long time to get

# %% [markdown]
# Return is the sum of all the rewards from the given state to the terminal state plus the discount factor which is the number less then the 1 like 0.9

# %% [markdown]
# gamma is used to represent the discoutn factor

# %% [markdown]
# The gamma makes the algorithm impatient as the intial rewards that the algorithm gets are the 100% but as the step increase we take the cube of the gamma and so one so it will increase and then it will decrease the reward thus making the algorithm try to get the reward as soon as possible

# %% [markdown]
# Genrally the discount factor is close to the 1

# %% [markdown]
# ![](Images/example_return.png)

# %% [markdown]
# We can see that based on that that always going to the left has better return then always going to the right but we do not have the always go left or right we can go left or right as well sometimes meaning right right left or left right left

# %% [markdown]
# ![](Images/left_right.png)

# %% [markdown]
# See this is better then both as we are not only going in the one direction only

# %% [markdown]
# If the state has the negative reward then what the function does is that it delays the negative values and make them postpone in the future as much as possible

# %% [markdown]
# ## Making decesion in Reinforcement learning : Policies

# %% [markdown]
# ![](Images/policiy.png)

# %% [markdown]
# There are many different actions that we can take in the reinforcment learning

# %% [markdown]
# In reinforcement learning our job is to come up with a function or policy that take in a state S and spit out an action a that its want us to take

# %% [markdown]
# For example for the last state our policy can be like this

# %% [markdown]
# ![](Images/policy_last_step.png)

# %% [markdown]
# ![](Images/goal_of_reinforcement_learning.png)

# %% [markdown]
# ## Key concepts

# %% [markdown]
# ![](Images/key_concepts.png)

# %% [markdown]
# ### Markov Decision Process

# %% [markdown]
# We have the agent and we do a action a and based on our action world or enviorment changes and based on the change we get the state or reward and do this

# %% [markdown]
# ![](Images/mdp.png)

# %% [markdown]
# Meaning all the steps above are formally called the MDP

# %% [markdown]
# ## State action value function

# %% [markdown]
# ![](Images/state_action.png)

# %% [markdown]
# Its typically denoted by Q and it takes in the state and the particular action that we take in that state

# %% [markdown]
# The Q will return a number that if we start in the state s and take action a once and then behave optimally after that meaning taking the action that does the maximum return

# %% [markdown]
# If we start at the state 2 and go to right and after it we behave optimally and go to left , left and we will go the terminal state and when we calculate the value will be 12.5

# %% [markdown]
# This is also called the Q function

# %% [markdown]
# #### Picking actions

# %% [markdown]
# Once we have know the values of the q functions that it will also help us picking the actions as well if we know all the values if we take the different actions then we will go where there is high value of the q function and will try to maximize it

# %% [markdown]
# ![](Images/all_values.png)

# %% [markdown]
# For example in the state 2 if we go left its the best reward that we can get in that state so we will go there

# %% [markdown]
# If we have a way of computer q for every state and action then we can choose the best possible action in every state

# %% [markdown]
# ## Bellman Equation

# %% [markdown]
# We use the bellman equation to compute the state action value function

# %% [markdown]
# ![](Images/equation.png)

# %% [markdown]
# Belleman example

# %% [markdown]
# ![](Images/belleman_example.png)

# %% [markdown]
# In the terminal state the equation Q(s,a) = R(s) only beacuse there is no new state as s' or a' thats why

# %% [markdown]
# ![](Images/explnation.png)

# %% [markdown]
# The equation in the blue is the equation that we were using it can be summed up into a single bellman equation as both have the same effect

# %% [markdown]
# The reward that we get immediatly is called the immediate result

# %% [markdown]
# ## Random environment

# %% [markdown]
# In some enviorments if we take a action into a new state its not compltely reliable for example window blowing etc

# %% [markdown]
# ![](Images/example_stochastic.png)

# %% [markdown]
# Based on the given example see if we command robot to go the left there is a 90% chance it does it but 10% chance due to wind or any other issue it can fail it and go the opposite direction this is called the stochastic enviorment

# %% [markdown]
# So in the stochastic enviorment we do not focus on maximizing the return beacuse in the end its a random number we can get lucky or not lucky and instead we want to maximize the average of the return

# %% [markdown]
# So the job of the algorithm will be to choose the policy to maximize the average return

# %% [markdown]
# ![](Images/expected_Return.png)

# %% [markdown]
# ![](Images/expected_bellman.png)

# %% [markdown]
# The bellman equation is also changed to the expected values mean we take average of the values and based on these averages we decide on what to do and what not to do

# %% [markdown]
# ## Continuos state space

# %% [markdown]
# ![](Images/continous_state.png)

# %% [markdown]
# In the above examples of the robot that we have been using we were using the discrete states in which there were discrete number of states like 6 for the example

# %% [markdown]
# Most real life applications can be in any number of continous space like a range of 0 to 6 km now it can be between these numbers in any range

# %% [markdown]
# For example building a truck can control x position y position as well as orientation etc all will be included in the state of the truck

# %% [markdown]
# State can have more then one values like x position , y position , orientation ,

# %% [markdown]
# ### Example

# %% [markdown]
# ![](Images/example_continous_State.png)

# %% [markdown]
# The dot means the change in the things meaning the speed etc

# %% [markdown]
# For a helicopter its state can include the following things

# %% [markdown]
# - X position (forward , backward)
# - Y position (left , right)
# - z position (up , down)
# - roll
# - pitch
# - yaw
#
# (The last three are for the orientation of the )

# %% [markdown]
# ## Lunar lander

# %% [markdown]
# In this we have to land the lunar lander meaning a shuttle on the moon by launching the thruster at the right time to slow down the  approach and land it safely

# %% [markdown]
# If the reinforcement algorithm work well then the lander will land in the proper way

# %% [markdown]
# ![](Images/lunar_landar_good.png)

# %% [markdown]
# If the algorithm does not work well then the lander will be

# %% [markdown]
# ![](Images/lunar_landar_fail.png)

# %% [markdown]
# For this application we will have the four possible actions

# %% [markdown]
# - do nothing
# - left thruster to move right
# - main thruster to move up
# - right thruster to move left

# %% [markdown]
# Our job is to keep picking these actions until finally we can land the lander between the flags

# %% [markdown]
# States for this is x , y , velocity x , velocity y , angle , angular velocity , l , r these two are to decide that wheather the left or the right leg of the rover is on ground or not

# %% [markdown]
# ![](Images/lunar_lander_state_action.png)

# %% [markdown]
# ![](Images/reward_lunar.png)

# %% [markdown]
# Based on the behaviour that  we want the algorithm to do we specify the reward function if we want it to move left right less we add a cost there so it stops it and so on

# %% [markdown]
# The final lunar problem is that

# %% [markdown]
# ![](Images/final_problem.png)

# %% [markdown]
# We have to find such policy that maximize the return

# %% [markdown]
# For this we will use the high value of gamma like 0.985

# %% [markdown]
# ## Learning the state value function

# %% [markdown]
# In the reinforcement learning we will take the state and different actions and pass it to the neural network and compute the q for different actions and then we will pick the action that maximize the Q

# %% [markdown]
# ![](Images/deep_learning_reinforcement.png)

# %% [markdown]
# If we train the neural network to give the appropriate answer for the Q(s , a ) then whenever our lander is any position we can compute the q(s , a) for all the values and pick the largest value

# %% [markdown]
# ![](Images/bellman_equation_data.png)

# %% [markdown]
# Using the bellman equation we will compute the x and y and get the number of the training examples and using the supervised learning we will train the neural network

# %% [markdown]
# We will collect the data using the bellman equation based on the data we will find the y and then train neural network on this data so using supervised learning it can predict the values

# %% [markdown]
# Our data points will be like this

# %% [markdown]
# ![](Images/s1.png)

# %% [markdown]
# The y we will be R(s) meaning reward in the state and the new state

# %% [markdown]
# Together they will form the training example

# %% [markdown]
# ## Learning Algorithm

# %% [markdown]
# ![](Images/learning_algorithm.png)

# %% [markdown]
# In the first step like in the linear regression we picked the parameters randomly and then improved it using the gradient desecent just like that we are also randomly quessing the Q(s ,a)

# %% [markdown]
# When training the neural network the max q(s` , a') will b radom guess and will improve over time

# %% [markdown]
# ## Improving the neural network

# %% [markdown]
# ![](Images/modified_neural.png)

# %% [markdown]
# Instead of neural network only outputting single q value in a single action it computes q for all the actions in that state thats why we can pick the q best

# %% [markdown]
# and since we are getting q for all the actions we can compute the max in bellman equation

# %% [markdown]
# ## Epsilon greedy policy

# %% [markdown]
# In the learning algorithm our first step is to take action in the lunar lander but when the algorithm is leanring we do not know which action to take

# %% [markdown]
# ![](Images/choosing_action_while_learning.png)

# %% [markdown]
# If we randomly pick the q function that defines that q of main is always low the algorithm will never pick it so we will not have any examples regarding it thats why in step 2 of option 2 we pick a random action

# %% [markdown]
# The option 2 is called the epsilon greedy policy where epsilon is 0.05 that is the probability of picking an action randomly

# %% [markdown]
# Generally we start with the epsilon high so we can explore different actions and then gradually decrease the value of epsilion

# %% [markdown]
# ## Algorithm refinement: Mini-batch and soft updates

# %% [markdown]
# ![](Images/problem_with_large.png)

# %% [markdown]
# See if we take the example of the gradient descent and we have a large dataset lets take a million for example now if we use the gradient step so for each step we have to compute the average over the million values and then take a small step this will be very slow and inefficient

# %% [markdown]
# ### Mini batch

# %% [markdown]
# The idea of mini batch is to not use all the examples in each step of the gradient desecent we will pick m` for example a 1000 and in each step we will randomly pick a subset of those 1000 examples and for each step we train using those 1000 examples so it works quite well

# %% [markdown]
# ![](Images/mini_batches.png)

# %% [markdown]
# ![](Images/mini_batch_pro.png)

# %% [markdown]
# In the mini batch cost function the gradient descent will find the global minima but it will do it not in a direct way as with the subset of the examples it can sometime go in the wrong direction but it will converge in the end

# %% [markdown]
# ![](Images/for_learning_alo.png)

# %% [markdown]
# If we use mini batch for our learning algorithm instead of taking 10000 examples at onces we can take the  1000 example and then train the neural network this will make the iteration mussy but faster

# %% [markdown]
# ### Soft update

# %% [markdown]
# In the softer update instead of directly overwriting the parameter of the previous Q we softly update the parameters of the previous network

# %% [markdown]
# ![](Images/soft_update.png)

# %% [markdown]
# this 0.01 and 0.99 are the hyper parameters that we can set and based on em we can see the change
