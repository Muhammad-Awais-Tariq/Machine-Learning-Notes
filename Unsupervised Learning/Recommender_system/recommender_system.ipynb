# %% [markdown]
# # Recommender System

# %% [markdown]
# Most of the moderen websites like e commerce , food websites , streaming websites offer the recommendation to the users and most of the sales are generated by these recommendations so it plays an important role in the economic of the companey movie as well

# %% [markdown]
# ### Example

# %% [markdown]
# In a typical recommender system we have some number of user and some number of items that we want to recommend

# %% [markdown]
# ![](Images/recommender_example.png)

# %% [markdown]
# ### Using per item features

# %% [markdown]
# If we have features for each item such as genere of each movie etc then we can build the recommender system as

# %% [markdown]
# ![](Images/features.png)

# %% [markdown]
# We have added the two new features based on the movie for example first movie is a romatic movie so it has 0.9 rommance and its not an action movie so its 0 and so on we have these addition features

# %% [markdown]
# We introduce a new notation n now which are the number of the features and each movie has two features now

# %% [markdown]
# ![](Images/recommendation.png)

# %% [markdown]
# Its just like the linear regression for different user we can have the different values of w and b and based on them we can predict what will the rating b like for the first user he has given high rating to romatic movies so based on this we can predict his rating for another love movie so based on the features just like that we can predict the rating for the user

# %% [markdown]
# > Its lot like the linear regression but instead of using only one we are using different model for different user

# %% [markdown]
# ## Notation

# %% [markdown]
# ![](Images/notation.png)

# %% [markdown]
# ## Cost function

# %% [markdown]
# We will use the mean squared error and just like the linear regression we will choose the values of the parameters to reduce this mean squared error

# %% [markdown]
# ![](Images/mean_squared_error.png)

# %% [markdown]
# We will only sum over the movies where the user have given the rating as for  some movies the user havnt given any rating at all

# %% [markdown]
# ![](Images/final_cost.png)

# %% [markdown]
# This is the final cost function with the regulization added and if we reduce this we can come up with a very good prediction with the minimum parameters w and b

# %% [markdown]
# N is the number of features

# %% [markdown]
# ![](Images/final_cost_v2.png)

# %% [markdown]
# For the recommender system its ok to remove the constant mj as it will work fine without it

# %% [markdown]
# And if we reduce this cost we will finally have the parameters for the single user

# %% [markdown]
# We can do this for all the users as

# %% [markdown]
# ![](Images/cost_function_for_all.png)

# %% [markdown]
# For all the user we will take the sum for values of the user till the n

# %% [markdown]
# Its mostly like the linear regression except that instead of one model we are fitting one model for each of the user

# %% [markdown]
# ## Collaborative Filtering

# %% [markdown]
# If we do not have the features like how much the movie is romance or action we can make those features from the data as

# %% [markdown]
# ![](Images/collaborating_problem.png)

# %% [markdown]
# We do not have the values for our features

# %% [markdown]
# lets assume that we have the parameters for all the users

# %% [markdown]
# ![](Images/final_problem.png)

# %% [markdown]
# Since for all of these problems the value of the b is 0 so we can ignore it for all the next examples

# %% [markdown]
# Now we want how an algorithm can predict the features based on all these values of the parameters that have been given

# %% [markdown]
# Since we have the data and final rating for the movies we can deduce feature values as

# %% [markdown]
# ![](Images/final_prediction_parameter.png)

# %% [markdown]
# If we have the parameters and the final prediction or rating then we can take the reasonable estimate at what the final value will be

# %% [markdown]
# Using this we can continue for all the movies

# %% [markdown]
# > This works only beacuse we have parameters for all the user

# %% [markdown]
# ## Cost function for the collaborative filletering

# %% [markdown]
# ![](Images/cost_function.png)

# %% [markdown]
# If we have the parameters known before then using gradeint desecent etc we can easily minimize the cost function

# %% [markdown]
# For most ml features are given from the start but in it we can deduce the features from the data

# %% [markdown]
# ## Collaborative filtering

# %% [markdown]
# Now we will combine both the cost to learn the parameters and the cost to learn the features this way if we do not have the parameters we can predict both

# %% [markdown]
# Added the cost function by combing the both features and combine each of these to give the final prediction

# %% [markdown]
# ![](Images/combined_cost_function.png)

# %% [markdown]
# #### Minimizing combined cost function

# %% [markdown]
# X is the features of all the movies

# %% [markdown]
# ![](Images/gradient_descent_for_collaborative.png)

# %% [markdown]
# Since there is now features as well with the parameters w and b now the new gradient descent will have the parameters w b and x

# %% [markdown]
# ### Binary labels

# %% [markdown]
# Most of the real world recommender system instead of displaying the proper rating just display a binary value like weather the user like the item or not so 0 or 1

# %% [markdown]
# ![](Images/binary_label_example.png)

# %% [markdown]
# The 1 mean that the user liked the movie the 0 mean he havent and ? mean that he havent seen it at all

# %% [markdown]
# In the collborative filtering this 0 and 1 can be discribed in number of ways like

# %% [markdown]
# ![](Images/label_example.png)

# %% [markdown]
# Based on the different criteria the label 0 and 1 describes the different crieteria

# %% [markdown]
# ### Changing the model from regression to binary classification

# %% [markdown]
# ![](Images/logistic_regression.png)

# %% [markdown]
# Now we have taken our function which was predicting the number to predict the probability of 1 meaning changing it to the logistic regression

# %% [markdown]
# ### Cost function

# %% [markdown]
# ![](Images/binary_cost_function.png)

# %% [markdown]
# This is the binary cost function

# %% [markdown]
# ## Mean normalization

# %% [markdown]
# Just like the linear algorithm if we normalize the feature before applying the model it would improve its performance same is the case with the recommender system if we normalize the rating before we run the algorithm it will also increase the performance of algorithm drastically

# %% [markdown]
# ![](Images/without_normalization.png)

# %% [markdown]
# If we have a fifth user who hvnt rated any movie and we apply the cost function without the normalization the function will predict the parameter for it to be 0 0

# %% [markdown]
# Based on these the algorithm will predict that he will give the rating of 0 to all movies

# %% [markdown]
# #### Mean normalization

# %% [markdown]
# We will take all the movies and compute the mean for all the movies

# %% [markdown]
# Then we will take all these mean and subtract the mean from the original values

# %% [markdown]
# Then these values will become the new values for the algorithm and based on it the model will learn the parameters

# %% [markdown]
# And when predicting we will add the mean again

# %% [markdown]
# Now even if the algorithm learn the parameter to b 0 and 0 for the new user but by adding the mean they model will predict the rating

# %% [markdown]
# ![](Images/mean_normalization_example.png)

# %% [markdown]
# By using the mean normalization the optimization algorithm also tend to work better

# %% [markdown]
# Instead of the rows we could also normalize the coloumns as well

# %% [markdown]
# ## Tensor Flow Implementation

# %% [markdown]
# ![](Images/tensor_flow_implementation.png)

# %% [markdown]
# Tensor flow will store the steps in the tape as well and will do it again and again until the gradient converges

# %% [markdown]
# This is called Auto Diff or Auto Grad as we are taking the derivative automatically using the tensor flow instead of manually computing the value

# %% [markdown]
# ### Adam optimization

# %% [markdown]
# The cost function is taking the parameters as well as the normalized rating who has given rating number of user number of movies and the regulization constant

# %% [markdown]
# ![](Images/adam_in_tensor.png)

# %% [markdown]
# The reason we can not use the layers etc its because this wont fit in the neural layers etc

# %% [markdown]
# ### Finding Related Items

# %% [markdown]
# ![](Images/related_items.png)

# %% [markdown]
# Collaborative filltering also give a nice way to find the relative items as well

# %% [markdown]
# When we use the algorithm to find the features x its hard to interpret them whats its like but collectively the group of these features do tell us what that movie is like

# %% [markdown]
# If we have a given a movie with features and want to find the similar movie we can do so by finding the item that has similar features to the original movie

# %% [markdown]
# By finding the squared distance between the two vectors and it will tell us which movie has the smallest distance

# %% [markdown]
# and those who have the least distance

# %% [markdown]
# ### Limitations of Collaborative Filtering

# %% [markdown]
# If we get a new movie or a new user is registerd with few rating what to show him collaborative filltering fails here and if we have new information about the user what these information can tell about the prefrence

# %% [markdown]
# ![](Images/limitation.png)

# %% [markdown]
# ## Collaborative filltering vs Content Based filtering

# %% [markdown]
# ![](Images/collaborative_vs_content_based.png)

# %% [markdown]
# In collaborative filltering we would recommend items to you based on ratings of users who gave similar ratings as you

# %% [markdown]
# In the collaborative we have some number of user who gave rating to some item and figure out how to recommend new items to you

# %% [markdown]
# #### Content Based filtering

# %% [markdown]
# In cotent based filterings the algorithm decide what to recommend to you based on the features of users and features of items to find a good match

# %% [markdown]
# It required having some features of the users and some features of the items as well and then decide which to recommend to whom

# %% [markdown]
# Example Features

# %% [markdown]
# ![](Images/features_example.png)

# %% [markdown]
# These are the set of features for each user and movies

# %% [markdown]
# Based on these rating we can deduce more features as well

# %% [markdown]
# Based on all these features the task is to decide wheather the give movie is a good match for the user

# %% [markdown]
# The feature vector for the user and movies can be of different size

# %% [markdown]
# ## Content based filtering : Learning to match

# %% [markdown]
# In the content based we will develop an algorithm that will learn to match the movies to the user based on the features

# %% [markdown]
# The first vector vu can tell us about the user preference that what he likes like how much he like romance movie , horror movies etc and the movie feature tell us how much a movie is romance or horror then doing the dot product of both can tell us the

# %% [markdown]
# ![](Images/different_feature_vector.png)

# %% [markdown]
# ## Deep learning for content based filtering

# %% [markdown]
# ![](Images/neural_netowkr.png)

# %% [markdown]
# For the each of the features of movies and user we will combine these to make the feature vector

# %% [markdown]
# To convert the features into the vector we will build a user network we will build a user network to convert the features into the vectors

# %% [markdown]
# Same will be applied to convert the movies features to the movies vector

# %% [markdown]
# The final layer in the network will have the number of neurons that we want to have the vector to have

# %% [markdown]
# The output layer of the both network have to have the same number of the neurons whereas the intermediate layers can have different number of neurons etc

# %% [markdown]
# ![](Images/sigmoid_function.png)

# %% [markdown]
# In the end we can use the sigmoid function for the both of the vectors to predict the probability of it being 1

# %% [markdown]
# ![](Images/combined_architecture.png)

# %% [markdown]
# The cost function for these will be similar to that of the collobrative filltering as well

# %% [markdown]
# ![](Images/combined_cost.png)

# %% [markdown]
# There is no sperate cost function for the movies or the user neural network speratly this is the combined way to find the cost of the both of the vectors

# %% [markdown]
# To find the similar movies like the above we will find the distance between the movies as well

# %% [markdown]
# We can pre compute the movies and find the similar movies to all of the movies so when a user come and see a movie he can also find the similar movies to it as well

# %% [markdown]
# ![](Images/user_movies_vector_deep.png)

# %% [markdown]
# ### Recommeding from large catalogue

# %% [markdown]
# Modern sites may have millions of movies , ads , songs or products to choose from and if for each user we feed the features through the neural network and compute the features for the user and the items of the cateloge to select which product to recommend it becomes very expensive

# %% [markdown]
# #### Working

# %% [markdown]
# This is normally done in two steps retrival and ranking

# %% [markdown]
# 1. In the retrival step we will pick a large list of the data  and this does not have to be accurate

# %% [markdown]
# ![](Images/retrival_step.png)

# %% [markdown]
# 2. In the second step we will take the list and then make the predictions based on that list and so instead of millions of movies we now have 100 movies that we rank and show the user the best one

# %% [markdown]
# ![](Images/ranking_Step.png)

# %% [markdown]
# We can compute the vm before hand so in the hand we will only need to compute vu

# %% [markdown]
# ![](Images/retrival_step_optimization.png)

# %% [markdown]
# ## Ethical use of recommender system

# %% [markdown]
# The recommender system can have postive as well as the negative use cases like

# %% [markdown]
# ![](Images/ethical_recommendation.png)

# %% [markdown]
# See if the recommender system is used to show the ads that is most likely clicked on or products generating the larges profit or video leading to maximum watch time it can b ethically concerning as well

# %% [markdown]
# In the travel industry its positive case but in the case of payday loans that exploits people it can be used in a negative way

# %% [markdown]
# ![](Images/ethical_concerns_exploitative.png)

# %% [markdown]
# ![](Images/problamatic_case.png)

# %% [markdown]
# See if we visit a video site which work on the maximizing the user engagement so it might push the videos that have hate speech etc as it tend to generate more views which would be wrong

# %% [markdown]
# ### Tensor flow implementation of content based filtering

# %% [markdown]
# ![](Images/content_based_filtering.png)

# %% [markdown]
# We are creating the user and item neural network  then we are getting the input and then based on the neural network calculating the values and then normlizing the values and then in the end doing the dot product and then find the final product

# %% [markdown]
# We use the keras dot layer to do the dot product

# %% [markdown]
# ## PCA

# %% [markdown]
# Its an algorithm that let us take the high dimenional data and reduce it to lower dimensions so it can b easy to plot and visualize

# %% [markdown]
# ![](Images/different_features.png)

# %% [markdown]
# There are multiple number of features for the car

# %% [markdown]
# ![](Images/choose_feature.png)

# %% [markdown]
# Since the varaince of x1 is greater we can simply take x1 to reduce the features

# %% [markdown]
# ![](Images/new_axis.png)

# %% [markdown]
# Now if the both features are being varied and are both usefull we will plot the new axis and make it size of the car and instead of both length and height we will use only the size feature

# %% [markdown]
# Pca is used to change the features from 10, 20 ,100 features to 2 or 3 features

# %% [markdown]
# ![](Images/from2d_to_3d.png)

# %% [markdown]
# If we have 50 features for the data we take these pca give us two featuers and we can plot em to visualize the data

# %% [markdown]
# ![](Images/conversion.png)

# %% [markdown]
# Based on the plot now we can visualize the data

# %% [markdown]
# ### PCA algorithm

# %% [markdown]
# Before the pca we should do the following steps

# %% [markdown]
# - Normalized the data to have zero mean
# - Feature scaling if different features have different scale

# %% [markdown]
# ![](Images/choosing_axis.png)

# %% [markdown]
# If we choose the axis instead of the 2d and we are converting it into 1d we can do it so by taking the examples and projecting it on the new examples its good as it can caputer the spread of the data still

# %% [markdown]
# Since the variance is large we are capturing the large information about the data

# %% [markdown]
# ![](Images/not_good.png)

# %% [markdown]
# This axis is not a good choice beacuse its not capturing the spread of the data as when we are projecting we are moving the poitns together

# %% [markdown]
# ![](Images/best_axis.png)

# %% [markdown]
# This is the best from all the examples as we are campturing the most information compared to any

# %% [markdown]
# This new axis is called principal component

# %% [markdown]
# ![](Images/corrdinate_new.png)

# %% [markdown]
# In order to find the new axis on the new principal component what we do is based on the direction of the componenet we take the components and do their dot product with the x and y axis to find the new components

# %% [markdown]
# If we pick the second axis it will be 90 to the second axis always

# %% [markdown]
# ![](Images/pca.png)
