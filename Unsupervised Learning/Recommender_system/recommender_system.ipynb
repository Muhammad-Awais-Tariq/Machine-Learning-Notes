# %% [markdown]
# # Recommender System

# %% [markdown]
# Most of the moderen websites like e commerce , food websites , streaming websites offer the recommendation to the users and most of the sales are generated by these recommendations so it plays an important role in the economic of the companey movie as well

# %% [markdown]
# ### Example

# %% [markdown]
# In a typical recommender system we have some number of user and some number of items that we want to recommend

# %% [markdown]
# ![](Images/recommender_example.png)
