# %% [markdown]
# # Unsupervised learning

# %% [markdown]
# ### What is clustering?

# %% [markdown]
# #### Supervised learning

# %% [markdown]
# ![](Images/supervised_learning.png)

# %% [markdown]
# As we can see that in supervised learning for a given data set we have both input features and output and based on that our logistic regression model can easily define a boundary so split the both data points

# %% [markdown]
# ### Unsupervised learning

# %% [markdown]
# In the unsupervised learning we are not given the output label y just the input without any output and beacuse we do not have the target label we can not tell the algorithm which data is right or wrong so we tell the algorithm to find something interesting about the data

# %% [markdown]
# ![](Images/unsupervied_learning.png)

# %% [markdown]
# For the following example we have only black dots beacuse we do not know the labesl which is right and which is wrong thats  y

# %% [markdown]
# The first unsuperviesed learning that we are going to discuss is called clustering

# %% [markdown]
# In the clustering the algorithm see that can i group together the points that are similar to one another

# %% [markdown]
# For example for the above example based on where the points are present the algorithm may find that it can devide the data into two clusters like the above image

# %% [markdown]
# ![](Images/clustering.png)

# %% [markdown]
# ### Application of clustering

# %% [markdown]
# The clustering can be used to
# - Grouping similar news
# - grouping people based on their interest
# - grouping people based on the dna analysis
# - astronmers using clustering to perform the astronomical data analysis by grouping similar body together

# %% [markdown]
# ![](Images/application_of_clustering.png)

# %% [markdown]
# ## K means clustering

# %% [markdown]
# The most common type of clustering algorithm that is used today is k mean clustering

# %% [markdown]
# Example

# %% [markdown]
# ![](Images/clustering_example.png)

# %% [markdown]
# If we have data like this and we want to devide it into two clusters the algorithm will work as

# %% [markdown]
# ![](Images/first_step.png)

# %% [markdown]
# In the first step the algorithm take the intial guess of where the center of the two clusters are and its not an accurate guess as it does not have to be

# %% [markdown]
# K means will do two things always:
# 1. Assign different points to cluster centeroids (these cross which it think is cluster center)
# 2. Move the cluster centeroids to the center of data

# %% [markdown]
# The very first thing the k mean is doing that its guessing the center of the data called the cluster centroids

# %% [markdown]
# ![](Images/centeroids.png)

# %% [markdown]
# After the algorithm has taken the intial guess at where it think the center is it will go through all the data points and for each point it will check to which cluster centriod that point is closer to and it will assign the point to that cluster

# %% [markdown]
# ![](Images/second_step.png)

# %% [markdown]
# At the second step the algorithm will look at all the red points and take the average of all of those red points or a group of points and move the cluster cenetorid at that point

# %% [markdown]
# ![](Images/finding_avearge.png)

# %% [markdown]
# Now it will do the similar thing for the blue dots as well}

# %% [markdown]
# ![](Images/reclculating_cluster_center.png)

# %% [markdown]
# Now onces it done and we have better guess for the center of the data we will look again at all the data and repeat the steps assigning the points that is closet to one center averaging and moving the centeroid again

# %% [markdown]
# ![](Images/recolored.png)

# %% [markdown]
# Onces based on the ceneteroid the points are recolored we will again find the average to move the centeroid there

# %% [markdown]
# ![](Images/again_moving_center.png)

# %% [markdown]
# Now we will  reapeat again first check the average location of all the points and move the ceneteroid to the average

# %% [markdown]
# ![](Images/new_location.png)

# %% [markdown]
# And if keep on repeating these points and finally a point will reach where there is no change in the color of the points or the position of the cluster ceneteroids this mean that at this step k means algorithm has converged and we have done our function

# %% [markdown]
# So finally the data is clustered accordingly

# %% [markdown]
# ![](Images/final_cluster.png)

# %% [markdown]
# ## K means algorithm

# %% [markdown]
# K mean the number of clusters that we want

# %% [markdown]
# Ceneteroids are the vector objects that have same dimenions as the training data

# %% [markdown]
# In the first step we find the distance between the point and the ceneteroid and we want to find the k that minimizes that distance

# %% [markdown]
# In the practice we minimize the square distance instead of the normal distance

# %% [markdown]
# If the example is closer to mue1 meaning our first cluseter so for that example we will set c = 1 or that mean we will set its color to be equal to 1

# %% [markdown]
# ![](Images/first_Step_in_algor.png)

# %% [markdown]
# Then in the second steps we will find the average or the mean of points assigned to the cluster k

# %% [markdown]
# ![](Images/second_step_algorithm.png)

# %% [markdown]
# Each of these points has two numbers in it x1 and x2 as they are the features so the location for the cenetroid will also have 2 numbers but if the number of features increase so does the points the in the location will also increase

# %% [markdown]
# #### Edge case

# %% [markdown]
# There is an edge case that what happens if the cluster has 0 values assigned to it

# %% [markdown]
# ![](Images/edge_case.png)

# %% [markdown]
# The most common fix in this case is to remove that cluster so for the above example instead of two we will end up with just 1 cluster

# %% [markdown]
# If we really need 2 cluster we can reassign the cluster ceneteroid in hope that it get assigned to some points

# %% [markdown]
# But the first way is the most common one

# %% [markdown]
# ### K means for the clusters that are not that well sepearated

# %% [markdown]
# If the cluster are not well separated k means is mostly used for that as well

# %% [markdown]
# ![](Images/not_well_separated.png)

# %% [markdown]
# Even if the data is not well separated if we run the k means it will eventually group the data into the clusters even if the data is not well separated

# %% [markdown]
# ### Optimization

# %% [markdown]
# In supervised learning we have seen that the algorithms use a cost function to find the distance between the actual value and predicted value to calculate the loss and then use gradient desecent etc to minimize that lost

# %% [markdown]
# The k mean algorithm also optimize the cost function a special kind of cost function and it do it without the gradient desecent

# %% [markdown]
# C is the index of the cluster to which the training example as been assigned to meaning if its assigned to cluster 1 then the i for that specific example will also b 1

# %% [markdown]
# muek is the cluster centroid

# %% [markdown]
# mue c i tell us the centroid of the cluster to which the example was assigned to

# %% [markdown]
# ![](Images/terminologies.png)

# %% [markdown]
# ## Cost function

# %% [markdown]
# In case of the k mean clustering the cost is the average of the distance of the training example to the cenetroid of the cluster for that example squared

# %% [markdown]
# ![](Images/cost_function.png)

# %% [markdown]
# The k mean algorithm is trying to find the location of the centeroid as well as the assignment of the point to the cenetroid that minimize the distance between the both

# %% [markdown]
# ![](Images/example_cost.png)

# %% [markdown]
# In the above example the cost function will look from the cenetroid and start calculating all the distance between these examples squared and then find the avearage

# %% [markdown]
# Distortation is the cost function function

# %% [markdown]
# In the first step of the k mean algorithm when we assign the points to the centeroids we are trying to minimize the cost as much as possible by updating the values of the points that mean the c

# %% [markdown]
# In the second step when we move the cluster we uodate the mue to minimize the cost function

# %% [markdown]
# ![](Images/example_step_1.png)

# %% [markdown]
# If we have a simple example like two centeroids and a single point what the algorithm does in the first step is the assign it to cenetroid with the lowest distance meaning the lowest cost which in this case will be red one

# %% [markdown]
# ![](Images/example_second_step.png)

# %% [markdown]
# In the second step as we can see by the red that if our cenetroid is not at the center then we will have a large cost function but if we move it to the center or in other word mean of the cluster then the overall cost function will be reduction

# %% [markdown]
# The cost function or distortion for the k mean algorithm should always go down or in the worst case stay same if it ever goes up there is a bug in the code

# %% [markdown]
# If the function stops going down this mean that the k means has converged and we should stop

# %% [markdown]
# ## Intilizing k mean

# %% [markdown]
# The first step in the k mean clustering was to randomly intilize the cenetorids but the question is how to take the intial guess and how cam we take the multiple guesses to improve the performance of the algorithm

# %% [markdown]
# The k or the number of the clusters should always less then the number of the training examples and it does not make the sense to make the k less then m as there will not b enough example for the k

# %% [markdown]
# The step of randomly intilization is that in order to pick the mue randomly pick the k training examples and then assign the mue to these training examples

# %% [markdown]
# ![](Images/randomly_picking_example.png)

# %% [markdown]
# In this we pick the random training examples marked by the black circle and since we want the two cluster we intilized them at that example so based on it my final cluster will be like this

# %% [markdown]
# ![](Images/final_cluster_1.png)

# %% [markdown]
# Its different then the earlier examples where the centeroid were picked random outside the examples

# %% [markdown]
# With this method there is a chance we end up with a sitatuion like

# %% [markdown]
# ![](Images/worst_sitatuion.png)

# %% [markdown]
# This will change the cluster picking

# %% [markdown]
# ## Complex example

# %% [markdown]
# If we want to devide the given dataset in the different cluster then based on where we randomly assign or intilized the cluster it can greatly impact the final clustering

# %% [markdown]
# ![](Images/cluster_example.png)

# %% [markdown]
# The one on the top is the good intilization but for the other two the random assigment is not great

# %% [markdown]
# In the two bottom examples instead of the global minima both times the algorithm stoped at the local minima

# %% [markdown]
# If we want to have the better chance of finding the best random initlization is to run it multiple times and it will try to find the best optimization

# %% [markdown]
# If we run k means multiple times then we can pick the best solution from it by computing the cost function for all of the different runs of the algorithm and then choosing the one with the minimum cost function

# %% [markdown]
# If we want to run the k mean 100 time we can do it by

# %% [markdown]
# 1. Run the k mean in the loop
# 2. randomyl intialize the k mean
# 3. run the k mean until it converges
# 4. compute the cost function
# 5. repeat it
# 6. pick the clusters that has lower cost

# %% [markdown]
# ![](Images/random_k_mean_example.png)

# %% [markdown]
# ## Choosing the number of the clusters

# %% [markdown]
# The k mean algorithm require as input the number of the cluster that we need

# %% [markdown]
# For most of the problem the number of cluster can b ambigious so choosing it can b hard

# %% [markdown]
# like for this example some people can say that there are two cluster while other can say no there are 4

# %% [markdown]
# ![](Images/number_of_cluster.png)

# %% [markdown]
# Since its unsupervised we are not given the number of the clusters that we need

# %% [markdown]
# #### Elbow method

# %% [markdown]
# One of the method of choosing the number of the cluster is that we will run the k mean with different number of clusters and then plot the cost function

# %% [markdown]
# ![](Images/value_of_k.png)

# %% [markdown]
# But there is not always the elbow so another way of choosing the number of cluster is that

# %% [markdown]
# We are always doing the cluster to find the downstream purpose or the purpose for which we deviding the data  into the cluster so the one way to elvalute the k mean is that evalute it on the downstream purpose how well its performing on that purpose

# %% [markdown]
# For example for the t shirt sizing we are sizing the shirt based on the small medium or large but how many shirt there are that can b ambigious so based on the final purpose we have to assign the cluster

# %% [markdown]
# ![](Images/value_of_cluster_example.png)

# %% [markdown]
# Now depeding on the our purpose that do we want the two types of the t shirts or the 5 type of the shirts and then based on the our goal we can decide which value of the k we want to choose

# %% [markdown]
# ## Anomly detection

# %% [markdown]
# Anomly detection algorithm learns the normal data from the unlabelled data and when it sees the data thats unusual or anomalous it raises the flag

# %% [markdown]
# Example

# %% [markdown]
# We want to check if the engine of the aircraft is good or not we can use the anomaly detection if algorithm there can be number of features that we can check after the engine has been made and then we will collect the data to check how the most of the engines behave and after the algorithm has seen this normal data how much they heat produce etc and after that there is a new engine then we will check does it look similar to the previous data or not then we will flag it as anomaly

# %% [markdown]
# ![](Images/anomly_example.png)

# %% [markdown]
# ## Algorithm for the anomly detection

# %% [markdown]
# The most common way to detect the anomly is by the use of density estimation

# %% [markdown]
# In it when we give the algorithm dataset we will built a model that will predict the probability of x meaning what features of x have high probability and which values have less probability of being seen in the dataset

# %% [markdown]
# ![](Images/density_estimation.png)

# %% [markdown]
# When we have learn this probability of the x meaning what is the probability of the x that is arriving any new data point that came we can find its probability and if the probability of the new test is very small then we will flag it as anomly

# %% [markdown]
# ## Anomaly detection example

# %% [markdown]
# - Fraud detection:
# if we are running the website we can make the features of each user like how often they log in how many pages they visit typing speed etc and model all this feature and then we can predict the probability from that user how likely or unlikely it is to flag it

# %% [markdown]
# This type of algorithm is also used to find the finicial fraud as well

# %% [markdown]
# - Manufacturing: Anomly detection is also used in the manufacturing to see if the manufactured product is normal or not

# %% [markdown]
# - Its also used to monitor the different computers in the data center

# %% [markdown]
# ![](Images/anomaly_detection_example.png)

# %% [markdown]
# ## Gaussian distribution

# %% [markdown]
# If the probability of the x is determined by the normal distribution then it will look like this

# %% [markdown]
# ![](Images/guassian_distribution.png)

# %% [markdown]
# Px mean that if we get the 100 number form this distribution and plot it they will look normal this distribution tell us that if take practical infinite number of examples from this dirbution it will still be in the shape of the bell

# %% [markdown]
# For any value of the mean and varaice using the formula we can plot the distribution
