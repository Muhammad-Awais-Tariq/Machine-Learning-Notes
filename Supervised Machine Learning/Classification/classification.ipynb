# %% [markdown]
# # Classification

# %% [markdown]
# Its different from the regression as in classification our output can only take a small number of values instead of all the values

# %% [markdown]
# ![image](Images/Classification_example.png)

# %% [markdown]
# The clssification which has only two outputs is called binary classification binary meaning two as there are only two possible outputs and these outputs are called class or category both can be used interchangeable and they are be presented as true or false or yes or no or 0 and 1

# %% [markdown]
# The class meaning the group of values where the y is false or 0 is called the negative class and the other group is called the positive class

# %% [markdown]
# For example

# %% [markdown]
# Is this email spam ?

# %% [markdown]
# In it the email that is not spam is the negative class beacuse its giving no to our question and the email that is spam is the positve class

# %% [markdown]
# The negative and the positive class does not represent good or bad but they represent wheather the thing required is present or not so its concerend with the presance and the absence

# %% [markdown]
# ## How to build the classification Algorithm?

# %% [markdown]
# ![image](Images/classification_model_problem.png)

# %% [markdown]
# We can try to fit the straight line throught this model but it wont work beacuse the regression will predict all the values less then 0 or grater then 1 but we want the data to be in the different catergories so its not going to work

# %% [markdown]
# ![image](Images/fitting_classification_model.png)

# %% [markdown]
# Instead of taking all the values we can design the model in such a way that we pick a tharsehold a value if the model predicts a value greater then that threshold in our example 0.5 then the model will predict the positive class else the negative one and if we draw the line where it interesect the straight line we can see that everything to the left of that line it will predict 0 and to the right will be 1

# %% [markdown]
# ### problem

# %% [markdown]
# This has a serious problem if we add more training data then the line will shift and keeping the same thershold it will start to classify the right values as wrong as well

# %% [markdown]
# ![image](Images/regression_fitting_problem.png)

# %% [markdown]
# This deviding line that devidies data on which group to classify into which class is caleed the boundry line

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Its the most used classification algorithm

# %% [markdown]
# ![image](Images/logistic_Regression.png)

# %% [markdown]
# In logistic regression instead of fitting the straight line we find the curve like s shaped curve that fit the data so when the new data comes according to which points its closer to it classifies it as that

# %% [markdown]
# ## Sigmoid function

# %% [markdown]
# Its a function denoted as $\ g(z) = \frac{1}{1 + e^{-x}}$ it gives the output between 0 and 1 and thats y its used in the classification the graph of this function looks liks this

# %% [markdown]
# ![image](Images/sigmoid_function.png)

# %% [markdown]
# In this if the z has very large value then e raise to that power negative will make it small so its value will b close to the 1 and in the opposite case if its very small then it will make the result close to the 0

# %% [markdown]
# And when  the value of the z is 0 then g(z is 0.5)

# %% [markdown]
# ## Converting this sigmoid function to logistic regression algorithm

# %% [markdown]
# In order to convert the sigmoid to the logistic we know that the basic defination of the linear regression is wx +b

# %% [markdown]
# We take it assign it to the value z and then we pass that z to the sigmoid function

# %% [markdown]
# ![image](Images/logistic_regression_model.png)

# %% [markdown]
# ### Interpretation of output of logistic regression

# %% [markdown]
# The logistic regression model will give us the probability that the class is 1

# %% [markdown]
# ![image](Images/logistic_Regression_output.png)

# %% [markdown]
# If the patient comes in of certain tumor and our model returns the value 0.7 it means that its 70 percent sure that its malignant and 30 percent sure that its not and the probability of both should be equal to one that is 0.7 + 0.3 = 1

# %% [markdown]
# ## Decision Boundary

# %% [markdown]
# In order to make the decision we have  to define a thershold its a point that we define above it we predict that the value is 1 and below that we take that its 0

# %% [markdown]
# ![image](Images/threshold.png)

# %% [markdown]
# The threshold is show by the purple dotted line

# %% [markdown]
# A common choice is to pick the threshold 0.5

# %% [markdown]
# ![image](Images/threshold_value.png)

# %% [markdown]
# Now the question is when the f(x) our function is greated then 0 we know that it depends on the sigmoid function g(z) and which is positive when the z is greated then 0 and the z depend on the wx + b so when its greater then 0 then the output will be above 0.5

# %% [markdown]
# ![image](Images/model_prediction.png)

# %% [markdown]
# ### Decesion boundary

# %% [markdown]
# Its the line where we are netural about our prediction that the y can either b 0 or 1 for it we take the value z = wx + b = 0 beacuse at this point we are neutral about y can be 0 or 1

# %% [markdown]
# ![image](Images/decision_boundary.png)

# %% [markdown]
# This purple line is the decesion boundary now we have made the decision boundary if we have the parameters equal to 1 and b = -3 using the value of the z we can make the decesion boundary line above that line model will predict 1 and below will predict 0

# %% [markdown]
# ### Non linear decision boundary

# %% [markdown]
# ![image](Images/non_linear_decision.png)

# %% [markdown]
# In case of the non linear decision boundary just like the polynomial regression we use the same concept to build the non linear logistic polynomial regression

# %% [markdown]
# ![images](Images/non_linear_boundary.png)

# %% [markdown]
# Now based on this we can see that the decesion boundary is like this based on this everything thats insize the circle is less then 1 so the prediction will b 0 and everything outsize the circle is greater then 1 so the prediction will be 1

# %% [markdown]
# If we have the polynomials of the higher degree then we can have the decision boundary take on the complex shapes as well so its not limited to circles and straight line

# %% [markdown]
# ## Cost function for logistic regression

# %% [markdown]
# The cost function in the logistic regression tell us what features do we have to choose to make the logistic regression better

# %% [markdown]
# m is total number of the training examples and the single example is denoted by i

# %% [markdown]
# n is total number of features

# %% [markdown]
# and the target y has only two values 0 and 1

# %% [markdown]
# ![images](Images/logistic_regression_training_Set.png)

# %% [markdown]
# The question that we want to answer is how to choose the parameters w and b for this model that is

# %% [markdown]
# ![image](Images/choosing_parameter.png)

# %% [markdown]
# ![image](Images/squared_error_cost_not.png)

# %% [markdown]
# Note in the squared cost error the 1/2 is inside instead of out of summation to make the math simpler

# %% [markdown]
# We do not use the squared error cost for the logistic regression because unlike the linear regression which is convex and has only one local minima and gradient descent can easily go to the local minima

# %% [markdown]
# In the logistic regression if we plot the function the cost and feature graph is not convex meaning that it has multiple local minima and the gradient descent can easily stuck on the minima

# %% [markdown]
# ## cost function for the logistic regression

# %% [markdown]
# So for the logistic regression we use the cost functions that convert the non convex graph of the cost function to the convex function so that gradient descent can be used

# %% [markdown]
# So in order to find the cost function for the logistic regression we have to change the cost function a bit

# %% [markdown]
# We introduce a new function called the loss function all the inside value the f and y without the square is denoted as the loss function and its summation find the overall cost

# %% [markdown]
# The loss function tell us how the model is doing for the specific example and by summing up all these losses we find the overall value of entire dataset

# %% [markdown]
# ![image](Images/loss_function.png)

# %% [markdown]
# Then using the piece wise function we define the function for the loss function depending on the actual value of the y is 1 we use one function and the loss is other for 0

# %% [markdown]
# ![image](Images/piece_wise_loss_function.png)

# %% [markdown]
# When the true value y is 1

# %% [markdown]
# ![image](Images/all_logistic_loss.png)

# %% [markdown]
# When we plot the log function we can see that its plotted like this the overall plot is like this but for  us the relevant part is that highlighted one as our logistic regression only predicts the values between these

# %% [markdown]
# When the actual value y is 1 the model tries to make the model move to 1 and the loss is lowest when the model predicts the values thats close to the true label y

# %% [markdown]
# When the true value y is 0 the plot is this

# %% [markdown]
# ![images](Images/logistic_regression_y_0.png)

# %% [markdown]
# When the y is close to the 0 in the case of the negative function then the closer the value is to the 0 the more the loss is 0

# %% [markdown]
# Depending on the model if the model predicts the value to be 1 or true but the actual value y is 0 so based on the model the model will get the large palenty

# %% [markdown]
# #### Conclusion

# %% [markdown]
# When the true label is 1 the model is strongly incentivized to not predict the value that are too closed to the 0 and the case is opposite for the other case

# %% [markdown]
# ![images](Images/cost_function_conclusion.png)

# %% [markdown]
# ### Simpler version

# %% [markdown]
# Since we are working with the binary classification the model can take up only two values we can come up with a simpler version for this cost and loss function

# %% [markdown]
# ![image](Images/simplified_loss_function.png)

# %% [markdown]
# The highlighted line is same as the above piece vise function

# %% [markdown]
# If the y is 1 then the equation become 1

# %% [markdown]
# ![images](Images/simplified_loss_Y_1.png)

# %% [markdown]
# See when the y is 1 it becomes the above term

# %% [markdown]
# If the y is 0 then

# %% [markdown]
# ![image](Images/simplified_loss_y_0.png)

# %% [markdown]
# ### Simplified cost function

# %% [markdown]
# ![images](Images/simplified_cost_function.png)

# %% [markdown]
# ## Gradient descent for logistic regression

# %% [markdown]
# It mean finding the good w and b to minimize the cost funciton

# %% [markdown]
# ![images](Images/gradient_descent_for_logistic.png)

# %% [markdown]
# Althogh the gradient descent for both linear and logistic looks the same but its not the same its beacuse the defination of fx has changed

# %% [markdown]
# To make sure that the logistic regression converges we can apply the same methood as for the linear regression

# %% [markdown]
# Both of these parameters have to be updated simutaneously

# %% [markdown]
# We can do the vextorized implementation for this as well as well as the feature scaling

# %% [markdown]
# ## Problem of overfitting

# %% [markdown]
# Lets again take the example of the price prediciting based on the size of the house using the linear regression

# %% [markdown]
# ![image](Images/fitting_straight_line.png)

# %% [markdown]
# The technical term for this is underfitting the model is underfitting the data

# %% [markdown]
# Another term is that model has high bias

# %% [markdown]
# In simple term the high bias and underfitting means that the model is not even able to fit the training data very well

# %% [markdown]
# In this the model is thinking that the price of the houses will be linear to the size despite the training set being none linear

# %% [markdown]
# ![images](Images/fitting_curve.png)

# %% [markdown]
# If we get the new house now based on this model it will probably predict is quite fairly compared to the linear one

# %% [markdown]
# We want algorithm to perform well on the examples that are not even on the examples that it has not seen this is called the generalization

# %% [markdown]
# ![images](Images/fitting_extreme_curve.png)

# %% [markdown]
# If we take the curve in such a way that it predicts the training set perfectly and the cost function is 0 then the model will perform well on the training set but will perform poorly on the unseen data

# %% [markdown]
# In this training even if the single point was change then the model will have picked entirely different function cz of overfitting

# %% [markdown]
# ![image](Images/underfit_normal_overfit.png)

# %% [markdown]
# In simple term the goal of the ml is to find the model that is not overfit or not underfit in simple term we want a model that is just right and in between these too models

# %% [markdown]
# ## fitting in classification

# %% [markdown]
# The problem of overfitting or underfitting is not applicable to regression only its also faced by the classification algorithms

# %% [markdown]
# ![images](Images/overfit_underfit_normal_in_classification.png)

# %% [markdown]
# ## Solving the fitting problem

# %% [markdown]
# If the model has overfitted our data one solution is to collect more training examples

# %% [markdown]
# ![images](Images/more_Training_data.png)

# %% [markdown]
# Another way to fix overfitting is to reduce the number of the features is to exclude and include the features

# %% [markdown]
# ![image](Images/feature_selection.png)

# %% [markdown]
# The disadvantage of using the selected features is that what if all the features are relevant for price prediction if we exclude some we may be throwing away some of the usefull features

# %% [markdown]
# Another way to solve this problem is by a methood called regularization

# %% [markdown]
# In regulization instead of straight up removing the feature like setting its value to the 0 it takes the general approach and shrink the values of the certain features

# %% [markdown]
# ![imaege](Images/regulization.png)

# %% [markdown]
# #### Conclustion for overfitting

# %% [markdown]
# There are three options to fix it
# 1. get more data
# 2. select the features
# 3. reduce the size regulization

# %% [markdown]
# Most commonely used is regulization

# %% [markdown]
# ## cost function for regulization

# %% [markdown]
# ![image](Images/regulization_intuition.png)

# %% [markdown]
# If we make the cost function which is to find the minimum cost by adding the large values like 1000 multiple by w3 and w4 the model will take the very less values of the w3 and w4 close to 0 so it can reduce the cost this way it will case the regulization

# %% [markdown]
# In the above example we penlized the w3 and w4 but for the real life example we do not know in advance which features we want to penalize or not

# %% [markdown]
# ![image](Images/regulizing_cost.png)

# %% [markdown]
# We use the new term called the lambda which is also called the regulization parameter

# %% [markdown]
# We devide the lambda by 2m as the cost function is devided by the 2m as well

# %% [markdown]
# We do not penalize b generally

# %% [markdown]
# With this new cost the algorithm does the two things the first thing that it do is to fit the training data well and the second thing is that it tend to reduce that problem of overfitting

# %% [markdown]
# The lamdas is use to balance both of these goals

# %% [markdown]
# ![images](Images/regulization_cost.png)

# %% [markdown]
# If lamda is 0 it means that we are not using the regulization term and get the overfitted curve like normal

# %% [markdown]
# ![image](Images/lamda_0.png)

# %% [markdown]
# If we make the lambda very large

# %% [markdown]
# ![images](Images/lamda_large.png)

# %% [markdown]
# If the lamda is very large then the model will make all the features approximatly equal to 0 and it will depend only on the b so it will cause the underfitting

# %% [markdown]
# Normal value of lambda will make the function look like

# %% [markdown]
# ![image](Images/lamda_normal.png)

# %% [markdown]
# ## Gradient descent with regulization

# %% [markdown]
# ![image](Images/gradient_descent_regulized.png)

# %% [markdown]
# The function for the b is same as we do not regulize the b but the w has the new reguliztion term added

# %% [markdown]
# These are also carried out simutaneously
