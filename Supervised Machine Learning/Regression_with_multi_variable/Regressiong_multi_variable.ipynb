# %% [markdown]
# # Linear_Regression_with_multiple_features

# %% [markdown]
# For example in the original example we have a single feature the size and based on that we predicted the price y and the model was simple f(x) = wx + b

# %% [markdown]
# ![image](Images/original_model.png)

# %% [markdown]
# But instead of only the single feature like the size we have multiple like no of beds floors as well as how old it is meaning we hv multiple features and we will have more information to predict the price of the house

# %% [markdown]
# Each of these features are denoted by the notation X<sub>1</sub> , X<sub>2</sub> ,  X<sub>3</sub>

# %% [markdown]
# In simple terms we simple write x<sub>j</sub>

# %% [markdown]
# where as the x<sup>i</sup> meaning the training example that we are talking about

# %% [markdown]
# and for sepecif example in the whole training example we will write x<sup>i</sup><sub>j</sub>

# %% [markdown]
# ![image](Images/multiple_feature_notation.png)

# %% [markdown]
# Previously the x was single number we simplly wrote wx + b but now we will write it as the sum of all of the features like w1x1 + w2x2 + w3x3 + w4x4 + b

# %% [markdown]
# Example

# %% [markdown]
# ![image](Images/multiple_feature_model.png)

# %% [markdown]
# Exaplanation

# %% [markdown]
# For example the based price is the starting big meaning the house will start at 80k and 0.1 is saying that for every square increase in the area the price will increase by 0.1 thousand dollar or simply by 100 dollars and the secong by each additional bedroom the price increase by 4000 dollar and for each floor the price increase by 10000 dollar and for each increase in the age the price of the house decrease by 2000 dollar so this is the model

# %% [markdown]
# ## general notation

# %% [markdown]
# In the single feature only w and b are the parameters of the model but with multiple feature the w is not a single value its a list of values and together with b and the list of values in w form the parameters for the model

# %% [markdown]
# And x is not a single feature as well its also a list of features

# %% [markdown]
# the x and the w are vetors simply meaning they are the list so thats y they have an arrow on top in the notation we can ignore it as well

# %% [markdown]
# ## Multple linear regression

# %% [markdown]
# Its a linear regression model with multiple features instead of writing the complex equation every time we assign the different values of the features and w parameter to the vector and take their dot product the dot product mean that x1 is multiply by w1 and so on so this is the complete model

# %% [markdown]
# ![image](Images/multiple_linear_regression.png)

# %% [markdown]
# ## Vectorization

# %% [markdown]
# When we implement an algorithm using the vectorization it will make our algorithm run efficently and make our code shorter as well and this vectorization allow us the take the advantage of using the gpu as well

# %% [markdown]
# If we have multiple features they are generally indexed from 1 we write the first feature as x1 and then in the w parameter we will write w1 but in python we will start the indexing from 0 so the first feature will be x0 and the first parameter will be w0

# %% [markdown]
# ![image](Images/indexing.png)

# %% [markdown]
# Without vectorization we can write the model as

# %% [markdown]
# ![image](Images/model_without_vectorization.png)

# %% [markdown]
# But this has an issue if the n is not 3 but 1000 this will be redunt to write as there will be multiple features

# %% [markdown]
# ![iamge](Images/efficent_without_vectorization.png)

# %% [markdown]
# While this one is more efficent that the above one but it still does not use the power of the factorization and the loop will cause the inefficencies further down the line

# %% [markdown]
# ## Vectorization

# %% [markdown]
# Instead of doing the dot and etc we can compute the dot product that is the same thing as multiplying w1 and x1 and with a single line can computer the whole value of the function

# %% [markdown]
# ![image](Images/vectorization.png)

# %% [markdown]
# The vetorization has two benefits

# %% [markdown]
# 1. It makes the code shorter
# 2. It make the code run much faster compare to the previous one

# %% [markdown]
# The vectorization is much faster then other two beacuse behind the scene is that  the dot product function in numpy can take advange of the parallel computation power

# %% [markdown]
# ![image](Images/vectorization_non_Vectorization_comparison.png)

# %% [markdown]
# See in the non vectorization we are performing the calculation step by step first we take one pair and then do it in t1 and so one but in the vectorization the computer take the complete array and multiple it with each element of other in one time stamp and then in the next time stamp sum them up together

# %% [markdown]
# ## gradeint descent

# %% [markdown]
# similar for the gradient descent that if we have 16 parameters and we hv their 16 derivatives and we calculate their values of parameters using the gradient descent without vetorization we will do it one by one but by using the vectorization we can do them parallely

# %% [markdown]
# ![image](Images/gradient_descent_vectorization.png)

# %% [markdown]
# In the numpy if we have vector arrays we can simply pass them as the number and the numpy will compute the values using the vetorization

# %% [markdown]
# ## Gradient Descent Implementation

# %% [markdown]
# ![image](Images/Gradient_descent_implmentation.png)

# %% [markdown]
# Now in the simple gradient descent we hv single parameter so we write x but for the multiple parameter we will have multiple values so we will write x1 to xn

# %% [markdown]
# ![image](Images/Gradient_descent_multiple_features.png)

# %% [markdown]
# ## Alternate to Gradient Descent

# %% [markdown]
# An alternative to using the gradient descent is normal equation while we know that descent is greate for minimizing the cost function to find the parameters

# %% [markdown]
# The normal equation is an algorith works only for the linear equation and it does not have any iteration and finds the value of w and b

# %% [markdown]
# Its disvantages inlcude that its not

# %% [markdown]
# 1. Its not generalized its for only one type of model thats linear regression
# 2. its quite slow when the number of features are large >10000

# %% [markdown]
# There is a chance that the ml library for the linear regression that we are using use normal equation methood to implement the linear regression

# %% [markdown]
# We do not need to learn how it works but just we should know that what it is

# %% [markdown]
# Generally the most used the gradient descent to find the parameters w and b

# %% [markdown]
# ## Techniques for Gradient descent

# %% [markdown]
# ### Feature scaling

# %% [markdown]
# If the feature has a large range and can choose the large values like from 300 to 2000 then the general rule of thumb is that the parameter value will be very small and if the feature has a relatively small range then the parameter value will b large

# %% [markdown]
# ![image](Images/feature_and_parameter.png)

# %% [markdown]
# Now in this example we can see that the range of the size of house is large and the number of bedrooms is small now if we take the large parameter value for the size and small for the number of bedrooms we can see that the model predicts a value which is much larger then the actual value

# %% [markdown]
# But if we take the small paramter for the size and large for the number we can see that the model prediction is more true

# %% [markdown]
# So this is the general case the model will generally pick the values that are small for the parameter with the large range and will pick the large parameter for the feature with small range

# %% [markdown]
# ![image](Images/change_in_feature_and_parameter.png)

# %% [markdown]
# By the model we can see that the very small change in the w1 can have a large impact on the final value and it take a very large change in the w2 to cause a small change in the final value

# %% [markdown]
# ### feature size and gradient descent

# %% [markdown]
# If we run the gradient descent in this we since the contour plot is thin and large the thing might happen that the gradient descent will have to run for a long time and it will go back and forth before it can finally reach the local minima

# %% [markdown]
# So to fix this its best to scale these values so they match and by scaling we mean that we do it such a way that both values take on a similar range

# %% [markdown]
# ![image](Images/gradient_descent_rescaled.png)

# %% [markdown]
# Now instead of having the range of size from 300 to 2000 and house from 1 to 5 we have scaled in such a way that both have same range and now we can see that the plot is also circular this way the gradient descent can easily find the minima thus increasing the efficency

# %% [markdown]
# ## Implementing feature scaling

# %% [markdown]
# #### Deviding by maximum

# %% [markdown]
# If we have the values of different ranges an easy way to is to devide each value in the range by the maximum this will give us the value in the minimum range it mean devinding by the first element till the last so we will have the range between these values

# %% [markdown]
# ![image](Images/Devding_by_max.png)

# %% [markdown]
# Now if we see the first one the range is from 0.15 to 1 beacuse 300 / 2000 is 0.15 and 2000/2000 is 1 so it take on this range of the values same is for the 0 and 5 so we have reduced the range of the values

# %% [markdown]
# #### Mean normalization

# %% [markdown]
# In the mean normalization we normalize the values in such a way that its center around the 0 and it takes on the values from -1 to 1 in both axis

# %% [markdown]
# ![image](Images/Mean_normalization.png)

# %% [markdown]
# See in it we take the mean of the both parameters and then for each one them we subtract the mean from the value and then devide by the max - min and this way we will have the values with the points in the center

# %% [markdown]
# #### z score normalization

# %% [markdown]
# In the z score normalization we use the standar deviation we find the standard deviation and then using it we find the new range for each of these values

# %% [markdown]
# ![images](Images/z_score_normalization.png)

# %% [markdown]
# ### rule of thumb

# %% [markdown]
# There are the acceptable ranges and if the range of the feature is beyound those features then we should rescale the values

# %% [markdown]
# ![image](Images/rule_of_thumb_for_rescaling.png)

# %% [markdown]
# There is no downside in the feature scaling so when in doubt we should just rescale the features

# %% [markdown]
# ## How to tell if the gradient descent is converging? (Finding the local minima)

# %% [markdown]
# To tell if the gradient descent is working properly one thing we can do is to plot the cost function with the number of iteration of the gradient descent (it means how many time we hv assigned the value to w and b )

# %% [markdown]
# This is called the learning curve
# there are different types of the learning curves

# %% [markdown]
# Based on this graph we can tell that after the iteration increase we can see that cost is changing and is decreasing if the gradient descent is working thats the behaviour the cost will reduce with each iteration

# %% [markdown]
# ![image](Images/Gradient_descent_converging.png)

# %% [markdown]
# If for onces the j increase it mean that the learning rate alpha is poor or there is a bug

# %% [markdown]
# The number of iteration needed by the gradient descent to converge can vary depeding on the application it mean need 30 iteration in one application in other it may need 500

# %% [markdown]
# A way to test if the model has done training is to do an automatica convergence test

# %% [markdown]
# ![image](Images/automatic_convergence_Test.png)

# %% [markdown]
# Its good practice to look at the graph or learning curve in comparision to the automatic convergence test

# %% [markdown]
# ## Chossing the learning rate

# %% [markdown]
# The performance of the algorithm depend on the learning rate alpha if its two small the algorithm will run slowly and if its too large the algorithm may not even converge

# %% [markdown]
# ![images](Images/problem_with_gradient.png)

# %% [markdown]
# See if we have learning rate like this its going up and down it mean two things
# 1. the code has bug
# 2. the learning rate is too large

# %% [markdown]
# Cause

# %% [markdown]
# Since we are using the alpha very large the cost when taking step can overshoot and follow the zig zag pattern

# %% [markdown]
# ![image](Images/cause_of_gradient_issue.png)

# %% [markdown]
# Fix:

# %% [markdown]
# In order to fix it we can use a smaller learning rate so the steps are short and it can converge easily

# %% [markdown]
# ![image](Images/fixing_gradient_descent.png)

# %% [markdown]
# Another issue caused by the large learning rate is that the cost is continuously increasing and is not deacreasing at all

# %% [markdown]
# ![image](Images/Increased_cost.png)

# %% [markdown]
# Its not always the case that learning rate is the only problem sometime the cost in the bug can also be the cause of the it for example instead of simutaneously updating the w and b we update w first then it will increase the cost with each iteration

# %% [markdown]
# ## Check if the gradient desent is working

# %% [markdown]
# To check if the gradient desent is working and does not have a bug with the small learning rate it should decrease with every iteration like .0001 and if its not then this mean that probably the code has bug

# %% [markdown]
# The small value of alpha is used as a debugging tool not in the actual code as the value small value will case the loose of the efficeny

# %% [markdown]
# Intial learning rate to try

# %% [markdown]
# we can try the range of the learning rates from

# %% [markdown]
# 0.001  |  0.01  |  0.1 |  1

# %% [markdown]
# For each of these value of the alpha instead of plotting the every iteration we should do it for a small number of times to see what the general graph of the learning rate is

# %% [markdown]
# In general pratice we should do it in such a way like for the first time we will increase the value of alpha by 3 times and then increase that by three times so it will be like this

# %% [markdown]
# 0.001 do it three times it will be  0.003 and its three is approxmitaly 0.01 and then increase it three times and so on

# %% [markdown]
# Eventually we will find the value that will deacrase the cost fast and consistently

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Choosing the right features for the tranning of the model can increase its efficency drastically and choosing these right features is called feature engineerning

# %% [markdown]
# ![image](Images/model_without_feature_engineering.png)

# %% [markdown]
# We can train the model simply like this and with these features the model might work okay on these two features if we train the model only on them
