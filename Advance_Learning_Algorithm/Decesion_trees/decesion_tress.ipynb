# %% [markdown]
# # Decision Tree Model

# %% [markdown]
# For example

# %% [markdown]
# We want to detect wheather an animal is a cat or not based on some features

# %% [markdown]
# ![](Images/cat_example.png)

# %% [markdown]
# In this examples the features input features take on the categorigal data meaning that they have discrete values instead of the numbers

# %% [markdown]
# The tree model for this example will be like this

# %% [markdown]
# ![](Images/tree_model.png)

# %% [markdown]
# Based on the example given this model will classify it as by starting at the top node then based on the features going into the required subtree and so on and in the end classifying the new example

# %% [markdown]
# ![](Images/1_decision_tree_model.png)

# %% [markdown]
# This is only one decision tree there can be multiple different decision tree for such problems like

# %% [markdown]
# ![](Images/multiple_decision_tree.png)

# %% [markdown]
# There are multiple ways to pick a decision tree now the main function of the decision tree model is to pick a tree that fits to the data perfectly and also generalizes well to the new data as well
