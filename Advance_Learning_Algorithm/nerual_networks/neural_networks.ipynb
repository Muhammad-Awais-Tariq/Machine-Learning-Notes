# %% [markdown]
# # Neural networks

# %% [markdown]
# The main inspiration for the neural networks is actually how our brain works

# %% [markdown]
# The neural network origin is to build an algorithm that try to mimic the brain

# %% [markdown]
# Neural networks in the moderen times have played a role in many technologies one of which is speech recoginition and much more complex include computer vision including image processing etc and after that it make its way into the text also called the natural language processing

# %% [markdown]
# Now ml is used for advertising, medical imaging and climate change and has diver application

# %% [markdown]
# Todays neural network has not much common with the working of the brain but the early origin was derived from the human brain

# %% [markdown]
# ## Working of brain

# %% [markdown]
# The human brain works with the help of the neurons the neuron use the electrical signals to convey the information from one part of brain to other and help in the thought formation feeling etc and by forming new connections

# %% [markdown]
# ![image](Images/brain_neuron.png)

# %% [markdown]
# The neruons take input from multiple direction like in the digram and perform some computation and convert it into output and that output in turn can be used as an input for other neurons and so on

# %% [markdown]
# This is the way of human brain working

# %% [markdown]
# A mathematical neuron for the ml take a input which can be one or more but is numerical meaning is a number and then it outputs a single number and that number can be used as an input for another neuron and so on

# %% [markdown]
# ![image](Images/biological_mathematical_neuron.png)

# %% [markdown]
# In building a deep learning algorithm instead of only taking on neuron we take multiple neuron that takes the inputs and provide the desired output

# %% [markdown]
# ### Real deal

# %% [markdown]
# In the todays world we have no real idea of how the brain work so we try to mimic with these model what little we know of the human brain and thats why we can not build the raw intelligence

# %% [markdown]
# Even with these simple algorithm we can build the power deep learning algorithms

# %% [markdown]
# ## Why now ?

# %% [markdown]
# The neural networks have been around since 1980s but they are gaining popularity now this raises a question as to why this is the case

# %% [markdown]
# As the amount of digital record has grown with the increase in the amount of the data it was difficult for traditional algorithm like linear regression or logistic regression to increase the efficency and they lacked behind with this data increase as we have more data and they were scaling properly

# %% [markdown]
# With the small neural network the performance will increase compare then the traditional models

# %% [markdown]
# ![images](Images/why_now.png)

# %% [markdown]
# ## Working of neural network

# %% [markdown]
# ### Example - Demand Prediction

# %% [markdown]
# In this we try to predict if a product will do good or not baseed on the data that we have collected the data of the different shirts sold at different prices and which of them became the top seller

# %% [markdown]
# Since there is only two classes we can use the logistic regression using the sigmoid function to find which class the data belong to instead of sigmoid function returned to f(x) we can return it to a which is called the activation it mean how much data the neuron is sending from one neuron to the other neuron

# %% [markdown]
# This logistic regression model can be thought of as a single neuron

# %% [markdown]
# ![image](Images/simple_neuron.png)

# %% [markdown]
# Now building a neural network requries bundling or putting multiple of these neurons together

# %% [markdown]
# #### Complex version of the problem

# %% [markdown]
# Instead of one feature now we will have multiple features that effect wheather a shirt is top seller or not

# %% [markdown]
# ![image](Images/complex_neruon_question.png)

# %% [markdown]
# Now we have four features price shipping cost marketing and material as the input feature to predict the probability of being a top seller

# %% [markdown]
# The t shirt becoming top seller actually depend on the affordability of the shirt how much aware the customer are of the shirt and whats the customer think is the quality of the shirt

# %% [markdown]
# Based on these now we can build the neural network as

# %% [markdown]
# ![images](Images/complex_neural_network.png)

# %% [markdown]
# A layer is a group of neurons that take in the group of the features and then in turn outputs few numbers together

# %% [markdown]
# A layer can have multiple neurons as well as single neuron

# %% [markdown]
# the final layer is called the output layer

# %% [markdown]
# The middle values of features like affordability awarness and quality are called the activations

# %% [markdown]
# So this neural network works as such it takes in 4 input numbers and then the layer 1 convert them into 3 numbers accordingly these numbers are called activation value and the final network returns the 1 number based on these three

# %% [markdown]
# ### Practical implementation

# %% [markdown]
# In practical we can not go and manually decide that which neuron has access to which features beacuse as the number of features will grow this will become more complex

# %% [markdown]
# In pratice it happens that every neuron as access to every feature or every vale from the input layer

# %% [markdown]
# And we will set parameters accordingly that each neruon will know that if it ignores certain value it can get the right answer and will start ignoring those features

# %% [markdown]
# ![image](Images/real_neural_implementation.png)

# %% [markdown]
# Or we can make it more simple by combining all these features into a feature vector x and then the middle layer use that feature vector x to predict the three values which are caleed the activation values they in term again turn into new vector which is then  used by other neuron to predict the final probability

# %% [markdown]
# ![image](Images/neural_networking_using_vector.png)

# %% [markdown]
# The middle layer is called the hidden layer

# %% [markdown]
# It can be taken as neural network is the form of logistic regression in this case that is taking in the input and then making its own features which it think will make it easier to predict the final probability and then using it for the final prediction

# %% [markdown]
# We also do not need to tell the neural networks the features like affordability awarness and preceived quality it will find these features on its own as well

# %% [markdown]
# ![image](Images/multi_hidden_layer.png)

# %% [markdown]
# The algorithm can have multiple hidden layers as well instead of having only one and this will effect its performance

# %% [markdown]
# ## Example 2

# %% [markdown]
# How image recognizing work

# %% [markdown]
# For example train a model in such way that takes in input the picture of a person and returns the identity of who that person is

# %% [markdown]
# ![image](Images/image_representation.png)

# %% [markdown]
# In the computer the image is represented in the form of the matrix with the same rows and coloumns as that of the original picture

# %% [markdown]
# And each value in that matrix has the pixel intesity value that what is the color

# %% [markdown]
# If we take all these values and convert them into a vector it will be of leangth 1 million as 1000 * 1000

# %% [markdown]
# And these will be our input vector

# %% [markdown]
# #### Problem?

# %% [markdown]
# The real problem will be that can we build a model that can take 1 million paramters and return the prediction

# %% [markdown]
# ## How model will work on this problem

# %% [markdown]
# For a problem like this the model can have multiple hidden layer where each layer will retun a certain output vector and it will be fed into different layers and then the output layer will give the final prediction

# %% [markdown]
# ![image](Images/image_model.png)

# %% [markdown]
# If we look that what those hidden layers are trying to find we may find that one neuron in the first layer is looking for vertical lines or horizontal lines in the image

# %% [markdown]
# In the early stages of the neural network its looking for thin lines and edges etc

# %% [markdown]
# in the next hidden layer we may see that neurons have learn to group the thin lines together to predict the different face parts

# %% [markdown]
# and if we look at the next layer we may see that neuron is looking for the face shape that how much a person looks like the certain person hes categorized

# %% [markdown]
# All of this is done by itself

# %% [markdown]
# #### Reacting to changed data

# %% [markdown]
# If we change the data for example instead of passing the picture data to the same model if we start passing it the images of the car or car data it will start learning from it how to find edges etc so without any help just based on the data it can tune its features as well

# %% [markdown]
# ![image](Images/car_model.png)

# %% [markdown]
# ## Neural network layer

# %% [markdown]
# ![image](Images/neural_network_layer.png)

# %% [markdown]
# the input layer input the 4 numbers and they are input to each of three neurons as the three of them get the same input numbers and all of those neurons are performing the logistic regression in their each step and each neuron will have their parameter w and b and based on it they will return a specific activation value and this activation value is the output

# %% [markdown]
# The combined output of all the neruons become the vector of the activation values for the next layer

# %% [markdown]
# To easily indentify a layer each layer has given a number the layer that takes in all our features or the first layer is called layer 1 and so on each layer has a specified number

# %% [markdown]
# To indentify the output of the sepecified layer we will denote the number in the superscript like a<sup>[1]</sup> it denote the first neural network layer

# %% [markdown]
# ![image](Images/neural_network_layer_2.png)

# %% [markdown]
# The input to the layer 2 is the output of the layer 1 and based on all these find the desired output that is the single prediction based on all these values

# %% [markdown]
# ![image](Images/neural_network_final_layer.png)

# %% [markdown]
# Now based on the final result of the neural network it will return the scaler quantity based on the thershold it will predict the final category

# %% [markdown]
# ### Complex neural network

# %% [markdown]
# ![image](Images/complex_neural_network_layer.png)

# %% [markdown]
# Layer 0 is the input layer

# %% [markdown]
# Layer 1 2 3 are the hidden layers

# %% [markdown]
# and the layer 4 is the output layer

# %% [markdown]
# In genral when we say that the network has 4 layers we do not count the input layers and are talking about the summ of all hidden layers and the output layer

# %% [markdown]
# ![image](Images/notation.png)

# %% [markdown]
# In this formula l is the specific layer and the j is the neuron of that layer

# %% [markdown]
# The g is the sigmoid function and its also called the activation function

# %% [markdown]
# The input vector can also be denotedd as a<sup>[0]</sup> as its the output from the layer 0

# %% [markdown]
# ## Inferencing (Making prediction)

# %% [markdown]
# This is an example of the algorithm called the forward propagation

# %% [markdown]
# For example

# %% [markdown]
# We are going to build a model to differentiate between hand written digit and for simplicity we can only inlucde the two numbers 0 and 1

# %% [markdown]
# To going to start we will use an 8 by 8 image for the training

# %% [markdown]
# ![image](Images/handwritten_digit_recognition_problem.png)

# %% [markdown]
# In order to perform the computation to convert the 64 (8*8) features into a prediction each layer will perform the specific functionality or calculation to predict the values

# %% [markdown]
# First layer using the 25 neurons perform its calculations as

# %% [markdown]
# ![image](Images/a_1_computation.png)

# %% [markdown]
# Then the second step is to compute the a2 the second layer value

# %% [markdown]
# ![image](Images/a_2_computation.png)

# %% [markdown]
# Now the last step is to compute the a3 we will compute it with the same steps as well but with the additional probability as well that based on the threshold is the number 1 or not

# %% [markdown]
# ![Image](Images/a_3_computation.png)

# %% [markdown]
# We can denote the whole output of the neural network as the function of the x

# %% [markdown]
# Since the output go from left to right its called the forward propagation beacuse generally we are moving forward

# %% [markdown]
# ![image](Images/foward_propagation.png)

# %% [markdown]
# using this we can download any neural network parameters and then train our model on it

# %% [markdown]
# ## Inference in code

# %% [markdown]
# Tensor flow the is the tool that is used for building the deep learning models the other one is pytourch

# %% [markdown]
# #### Implementing inferencing in tensor flow

# %% [markdown]
# The main thing about the deep learning is that a single algorithm can be applied to multiple different applications

# %% [markdown]
# Example

# %% [markdown]
# For this we take the example of the coffee roasting when roasting the coffee beans we have two parameters that we can control and these are temperature and the duration

# %% [markdown]
# ![image](Images/coffee_roast.png)

# %% [markdown]
# as we can see that if the coffee beans are cook at the lower temp they are undercooked if cooked for too short they are still not perfect and if cooked for too long and at high temp still not good only in the middle they are perfect

# %% [markdown]
# Now given the input vector of temp and the duration we have to find using ml that wheather the coffe will be good or not

# %% [markdown]
# ### Computing the probability

# %% [markdown]
# ![image](Images/tensor_flow_model.png)

# %% [markdown]
# We have the input features x in the input layer and then we are passing it to the first layer the dense is the type of layer that we are disscussing till now the units are the number of the neurons in the layer and the activation is the function that we are going to use to compute the value and to compute the a1 we will apply layer 1 as the function same for the layer 2 as well and the using the threshold will find the final value

# %% [markdown]
# we will know more about the different values in the lab

# %% [markdown]
# ### Data in the tensor flow

# %% [markdown]
#  ![image](Images/data_representation_q.png)

# %% [markdown]
# In order to store the matrix we use the double brackets to store a matrix rows and coloumns and the inside one represent each row

# %% [markdown]
# ![image](Images/matrix_representation.png)

# %% [markdown]
# In the question when we have created the np array with [[200 ,1 7]] it was creating a matrix of 1 x 2 meaning 1 row and 2 coloumns

# %% [markdown]
# ![image](Images/shapes_of_arrays.png)

# %% [markdown]
# The vector that has single row like the first example is called the row vector and the one that has one coloumn is called the coloumn vector

# %% [markdown]
# If we simple write in the single bracket it will be like the list that has no rows or coloumns and will be just in the 1d

# %% [markdown]
# In tensorflow its convention to use matrix to represent the data

# %% [markdown]
# So if go to the original example and print the a1 from it we will see that the three values that the first layer represent will be stored in the form of 1 x 3 matrix

# %% [markdown]
# Tensor is the data type that the tensor flow team has created to do the computation more easily its basically a type to represent the matrix

# %% [markdown]
# ![image](Images/original_example_data.png)

# %% [markdown]
# If we want the data to represent the data in the numpy instead of the tensor we can do a1.numpy and it will represent the data in the nump formay

# %% [markdown]
# Similary the second layer output will look like the 1 by 1 matrix

# %% [markdown]
# ## Building the neural Network

# %% [markdown]
# Instead of manaully using the layer 1 to compute the actvation 1 and then passing it to the layer 2 and so on we can just tell the tensor flow to build the model for us which it can do to carry out these for us

# %% [markdown]
# The ssequential tell the tensor flow the create the neural network by sequentialy using the layers provided

# %% [markdown]
# ![image](Images/neural_networl_architecture.png)

# %% [markdown]
# this is how we will train the model on the data and then inference using it on the new data

# %% [markdown]
# Instead of using the three lines we can simplfy them as

# %% [markdown]
# ![image](Images/neural_network_simple_architecture.png)

# %% [markdown]
# ## Forward propagation in a single layer

# %% [markdown]
# We are using the python code to depecit how the libraries like pytourch and tensor flow work

# %% [markdown]
# In the python the features are represented in the 1d array we do not need matrix as we are not using the tensor flow

# %% [markdown]
# w2_1 is same as the second neuron of the layer 1 its just the repsentation

# %% [markdown]
# ![image](Images/python_layer.png)

# %% [markdown]
# Just using python we can implement this by calculating each value of the neurons then finding the z value for each and then fiding the a1 we can finally find all the values

# %% [markdown]
# ### General implmentation of forward propagation instead of hardcoding

# %% [markdown]
# Instead of writing every neuron by self we can do it all by layer by layer

# %% [markdown]
# In it instead of passing the parameters indivisually we pass them as the matrix

# %% [markdown]
# ![image](Images/forward_prop_in_code.png)

# %% [markdown]
# First this function is finding the units by using the coloums shape the units is the number of neurons

# %% [markdown]
# then we are creating the empty array with 0 having the same size as that of the number of neurons beacuse we will give that many neurons as the output

# %% [markdown]
# in the for loop we are pulling the respected coloumn

# %% [markdown]
# then we find the z using the dot product

# %% [markdown]
# and then we compute the a out using the sigmoid function and then pass it to the array that we have intilized with the 0s
