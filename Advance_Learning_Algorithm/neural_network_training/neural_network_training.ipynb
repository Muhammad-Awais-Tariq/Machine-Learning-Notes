# %% [markdown]
# ## Training

# %% [markdown]
# ### Hand written digit recognition example

# %% [markdown]
# ![image](Images/neural_network_training.png)

# %% [markdown]
# In this code based on the training images that we are given that is photos of the handwritten 1 and 0 we train the model and its code can be written as

# %%
import tensorflow as tf
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.losses import BinaryCrossentropy 
model = Sequential([
Dense(units = 25 , activation = 'sigmoid'),
Dense(units = 15 , activation = 'sigmoid'),
Dense(units = 1 , activation = 'sigmoid'),
])

model.compile(loss = BinaryCrossentropy()) # Its compiling the model and when compiling the neural network we have to specifiy the loss function

model.fit(X , Y , epochs = 100) # the x and y are our features and the real output

# we are fitting the model the epochs is the number of steps or number of times we are running the model

# %% [markdown]
# ### Training Details

# %% [markdown]
# #### In logistic regression

# %% [markdown]
# In the logistic regression model our steps were as flows
# 1. Defining the model sepecifing how will we compute fx in the logistic regression it was the sigmoid function
# 2. The second step was the define the loss function (This was how well the model is doing) and the cost function which was computing cost for all examples as well and the cost is the average over the entire dataset
# 3. The third step is to use the algorithm like the gradient descent to minimize the cost and update the parameter continuously

# %% [markdown]
# ![image](Images/logistic_regression_steps.png)

# %% [markdown]
# Using the same three steps we can train the neural network model as well

# %% [markdown]
# ![image](Images/mapping_steps_to_neural_network.png)

# %% [markdown]
# #### Neural network steps

# %% [markdown]
# ##### Step1 : Creating the model

# %% [markdown]
# ![image](Images/step1_neural_network.png)

# %% [markdown]
# The given code snippet define the entire model it tell us how many layers the network will have what will be used as the activation and what are the number of neurons in each of these layers

# %% [markdown]
# ##### step 2 : Loss and cost function

# %% [markdown]
# ![image](Images/step2_neural_network.png)

# %% [markdown]
# The most common loss function that is used for binary classification problem in the neural network is the same as the one used in the logistic regression y is the target and the fx is the prediction

# %% [markdown]
# This loss function in the neural network is also know as binary cross entropy loss function

# %% [markdown]
# The binary cross entropy just tell the tensor flow to compute that loss function

# %% [markdown]
# If we have the linear regression problem and we want to minimize the mean squared error that occur in it we can use the model.compile(loss = meansquarederror()) to tell the model what we are talking about

# %% [markdown]
# This will be the loss function but the cost function is the function of all the parameters of the neural network

# %% [markdown]
# ##### Step3: Minimizing the cost function

# %% [markdown]
# ![image](Images/step3_neural_network.png)

# %% [markdown]
# We will use the gradient descent to minimize the parameter repeadtly and with each iteration it will assign the new values to the parameters and will compute the partial derivative and in order to compute the derivates for the gradient descent we use the back propagation

# %% [markdown]
# ### Alternatives to Sigmoid activation

# %% [markdown]
# We were building all the neural networks using the sigmoid activation as we were building from the notion of the logistic regression that we have covered and in simple we were using the number of logistic regression units and bundling them together

# %% [markdown]
# Using other activation function we can make the model much more powerfull

# %% [markdown]
# ![image](Images/previous_example.png)

# %% [markdown]
# Using this example previously we have defined that each of these as only 0 or 1 but what if there are values in between like a person can b less aware or very vary so instead of mapping awarness between 0 and 1 only we should assume it as any non negative value

# %% [markdown]
# The most common functions to use in this case instead sigmoid is to use the RelU (rectified linear unit )activation in which we use the max(0 , Z) to draw the model

# %% [markdown]
# ![image](Images/ReLU.png)

# %% [markdown]
# Here are some common types of activation functions

# %% [markdown]
# ![image](Images/common_activation_function.png)

# %% [markdown]
# In the linear activation function the g(z) and z are same so its like no activation function at all

# %% [markdown]
# ### Choosing the activation function

# %% [markdown]
# In the neural network we can chose the different functions for each of the neuron

# %% [markdown]
# ##### Choosing the function for output layer

# %% [markdown]
# Choosing the activation function for the neuron in the output layer is quite easy dependin on which kind of the output are we looking for if its 0 or 1 we can chose the sigmoid if only positive we can chose ReLU or if there is a range of values we can chose linear

# %% [markdown]
# ![image](Images/activation_function_for_output.png)

# %% [markdown]
# ##### Choosing the function for hidden layer

# %% [markdown]
# The most common choice for the hidden layers is the ReLU

# %% [markdown]
# ##### Reasons for choosing ReLU

# %% [markdown]
# 1. ReLu is faster to compute compare to the sigmoid
# 2. ReLU function is flat in only one place when the z is less then 0 but the sigmoid goes flat at 0 and 1 as well meaning on both places if we are using the gradient descent and a function is flat in only one place the gradient descent will perform much faster compare to if the function is flat at many places

# %% [markdown]
# ![image](Images/activation_function_for_hidden.png)

# %% [markdown]
# ### Summary of activation functions

# %% [markdown]
# ![image](Images/activation_function_summary.png)

# %% [markdown]
# ### Why we need activation functions ?

# %% [markdown]
# If we use linear activation in every neuron the neural network wont work beacuse it will just be the linear regression and will defeat the purpose of even using the neural network

# %% [markdown]
# ![image](Images/why_we_dont_use_linear.png)

# %% [markdown]
# We need activation functions other then the linear in the neural networks to seprate the neural network from the simple linear regression model

# %% [markdown]
# ### MultiClass

# %% [markdown]
# It refers to classification problem in which we can have more then one classes like instead of classifying the data into two classes like we were doing in the digit recognization instead of classifiying only into two classes if we have more then 2 classes like classifying all the numbers then this will be multi class classification

# %% [markdown]
# ![image](Images/multi_Class_classification.png)

# %% [markdown]
# ![image](Images/binary_multiclass_classification.png)

# %% [markdown]
# In the binary classification the algorithm draws the straight line boundary like this and it predicts wheater a value is 1 or not whereas in the case of the multiclass the algorithm divides the data into discrete number of classes and predict the probability of the data being 1 or 2 or 3 or 4

# %% [markdown]
# ### Softmax

# %% [markdown]
# Its the generalization of the logistic regression function to apply it to multi class classification

# %% [markdown]
# ![image](Images/logisitic_regression.png)

# %% [markdown]
# In case of the logistic regression to apply it to the multi class think of it as computing the two numbers that is the 1st being the probability that given number is 1 and the second is the probability that given number is 0 and this can be found by subtracting a1 from 1

# %% [markdown]
# ![image](Images/softmax_Regression.png)

# %% [markdown]
# The w1 and w2 and w3 and 24 and same for the b are the parameters of the sofmax regression

# %% [markdown]
# General form

# %% [markdown]
# ![image](Images/soft_max_general.png)

# %% [markdown]
# ### Cost for Sofmax regression

# %% [markdown]
# ![image](Images/cost_for_softmax.png)

# %% [markdown]
# The cost of the softmax is that we take the negative log os the specific value that we are looking to find the loss for and same as before it incentivizes the algorithm to take the proper value to reduce the loss

# %% [markdown]
# ### Neural Network for Sofmax output

# %% [markdown]
# If we want multiclass classification then instead of just 1 output neuron we will have number of nurons or units similar to our output classes we want 10 so the output will have 10 units as well and this output layer will be softmax output layer

# %% [markdown]
# And we will comptue a1 to a10 like this

# %% [markdown]
# ![image](Images/neural_network_with_softmax.png)

# %% [markdown]
# In case of the other activation function we only used that specific function of z as well but the activation function of softmax required all the values of the z in order to compute its values

# %% [markdown]
# ![image](Images/logistic_vs_softmax.png)

# %% [markdown]
# ### Implementation of softmax in Tensor Flow

# %% [markdown]
# ![image](Images/multi_class_in_tensorflow.png)

# %% [markdown]
# The sparse categorical loss function refer to classes since we are deviding into classes thats why we are using this loss function

# %% [markdown]
# #### The above code works and will fit the data but its not the recommended version to use

# %% [markdown]
# ### Improved Implmentation of Softmax

# %% [markdown]
# ![image](Images/multi_class_in_tensorflow.png)

# %% [markdown]
# If we use this message there are some problem these include

# %% [markdown]
# 1. The roundoff errors

# %% [markdown]
# ![image](Images/round_off_error.png)

# %% [markdown]
# The way we are computing the softmax cost function is good but it has the numerical roundoff error which can cause the issue

# %% [markdown]
# In the original function when we call the function it was insisting on computing the intermediatry term if we specifically tell the tensor flow what that term is it will reduce the overall neumerical roundoff error

# %% [markdown]
# ![image](Images/round_off_fix.png)

# %% [markdown]
# The above code makes that the final layer that was sigmoid it make its linear and pass the activation function and everything into the loss function calculation and tell it to compute the every value instead of computing intermeditry value

# %% [markdown]
# Logits are the value is z

# %% [markdown]
# ##### In case of the logistic regression either of the implementation works fine but in case of the softmax the roundoff error becomes more complex

# %% [markdown]
# ![image](Images/fixed_softmax.png)

# %% [markdown]
# This version is more numerically accurate

# %% [markdown]
# ![image](Images/final_softmax.png)

# %% [markdown]
# Since we have changed the last activation to be linear in order to make it more numerically accurate now if we call the predict directly it will not predict the classes thats why we will use the sofmax function from tensorflow

# %% [markdown]
# ### For logistic

# %% [markdown]
# ![image](Images/final_logistic.png)

# %% [markdown]
# ### Multi label classification problem

# %% [markdown]
# Its the type of the classification in the one image or input instead of one label there can be multiple output labels

# %% [markdown]
# ![image](Images/multi_label_classification_example_output.png)

# %% [markdown]
# So for a single input in this case image we have multiple output labels like is there a car bus or a pedestrian and in this case the output will be in term of a vector

# %% [markdown]
# ### Building a neural network for this problem

# %% [markdown]
# In order to build a neural network for this we can have two approaches

# %% [markdown]
# 1. Build neural network for each of the problem a neural network to detect bus a seprate for person a sperate for car and combine their output

# %% [markdown]
# ![image](Images/multi_label_classification_1st.png)

# %% [markdown]
# 2. The second approach is to train a neural network to simutenously detect all three outputs

# %% [markdown]
# ![image](Images/multi_label_classification_2nd.png)

# %% [markdown]
# In this case the final output layer will have three neurons to output the three labels correctly

# %% [markdown]
# And we can use the sigmoid in each layer to tell wheather the specific type is present or not

# %% [markdown]
# ### Advance Optimization

# %% [markdown]
# Gradient descent is an optimization algorithm that is widely used in the machine learning and is the foundation of many optimization algorithms

# %% [markdown]
# There are other algorithms that are even better then gradient descent for reducing the cost

# %% [markdown]
# Adam algorithm

# %% [markdown]
# Its the algorithm that see that if the learning rate is very small and we are going in the same direction it automatically increases the learning rate Alpha and if we have a large learning rate and we may overshoot the minimum point the adam algorithm automatically find the desired learning rate for  that as well

# %% [markdown]
# ![image](Images/adam_algorithm.png)

# %% [markdown]
# The adam algorithm does not use a single learning rate for all it has different learning rate for different parameters

# %% [markdown]
# The intuition of the adam algorithm is that if the parameter keep moving in the same direction like in the first example it increases the learning rate

# %% [markdown]
# The second step is that if the algorithm is osicilating meaning changing direction again and again it mean that its not going in the same directio so then we will decrease the learning rate alpha

# %% [markdown]
# ![image](Images/adam_algorithm_intiution.png)

# %% [markdown]
# In code the algorithm is implemented as

# %% [markdown]
# ![image](Images/minist_adam.png)

# %% [markdown]
# The adam algorithm does need an intial learning rate which we have to provide it

# %% [markdown]
# Its pratice to use some different values of the alpha to see how it effect the performance

# %% [markdown]
# ### Additional Layer Types

# %% [markdown]
# All the layer that we have used till this were the dense layer they are the layer in which all the neurons in the layer get all the activations from the previous layer

# %% [markdown]
# Using dense we can build powerfull algorithm

# %% [markdown]
# ![image](Images/dense_layer.png)

# %% [markdown]
# Convolutional layer

# %% [markdown]
# ![image](Images/convolution_layer.png)

# %% [markdown]
# In this type of the layer each neuron look at the part of the previous layer output

# %% [markdown]
# Benefits:

# %% [markdown]
# 1. It increases the computation speed
# 2. The model implmented with this layer need less training data
